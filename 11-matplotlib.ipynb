# %%
import matplotlib.pyplot as plt

# %%
x = [3,7,11,13,21]
y = [50,30,120,150,110]
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y, color="red", lw=5, ls="--", label="tourist number")
plt.legend()

# %%
import matplotlib.pyplot as plt
citya_m = [4,5,6,7,8,9,10]
citya_n = [68,120,480,1000,650,600,100]
plt.plot(citya_m,citya_n, label="City A")
cityb_m = [5,6,7,8,9,10,11]
cityb_n = [30,330,900,790,480,130,220]
plt.plot(cityb_m,cityb_n, color="red", linewidth=5, linestyle="--", label="City B")
plt.legend()
plt.xlim(3,11)
plt.ylim(0,1050)
plt.title("The tourist number after the flood")
plt.xlabel("months")
plt.ylabel("tourist number")
plt.show()
